# %%
from os import walk

## director of simulated data
PATH_DATA = "/Users/yl346355/Documents/Projects/synthea/output/fhir"

# %%
files = walk(PATH_DATA)

# %%
list(files)
# Out:
# [('/Users/yl346355/Documents/Projects/synthea/output/fhir',
#   [],
#   ['Willia886_Turcotte120_ebddf1aa-9e7c-4f54-b904-c3714b391334.json',
#    'Landon622_Wyman904_d256ab79-8182-4532-8495-af704cb19792.json',
#    'Donald774_Pagac496_510c0127-e656-483c-988b-682cdf80f430.json',
#    'Marjory382_Deckow585_4b74c072-baef-4842-9ee4-90065f9334a9.json',
#    'Leonor133_Hessel84_84e5aab4-377e-498c-bdf7-40d1ad4a6650.json',
#    'Hector463_Schulist381_bfd2b932-57fd-47e7-9572-c3d171851a00.json',
#    'Leonore418_Kuhn96_f58cb92b-df40-4bfb-ada7-147b56eb4e93.json',
#    'Rosario163_Littel644_ae3fd6c9-09ef-4283-9ac9-4702f7825fbf.json',
#    'Mario764_Páez758_bf88dd6c-f256-4835-9099-afbdffd4ca4d.json',
#    'Mike230_Jacobi462_5b540330-f3f2-47b6-b332-42436d3c1640.json',
#    'Sunshine777_Hermann103_37794674-e0a0-4cb6-a667-3acdc4e79e0e.json',
#    'Rayford811_Hoeger474_53390762-9f8e-4452-a589-edb0091d7c1c.json',
#    'Rosalina69_McCullough561_b8698f33-62d3-4734-9f83-d66c7f6b0ab5.json',
# ...

# %%
import pandas as pd
data = pd.read_json("/Users/yl346355/Documents/Projects/synthea/output/fhir/Willia886_Turcotte120_ebddf1aa-9e7c-4f54-b904-c3714b391334.json")

# %%
data
# Out:
#     resourceType         type  \
# 0         Bundle  transaction
# 1         Bundle  transaction
# 2         Bundle  transaction
# 3         Bundle  transaction
# 4         Bundle  transaction
# 5         Bundle  transaction
# 6         Bundle  transaction
# 7         Bundle  transaction
# 8         Bundle  transaction
# 9         Bundle  transaction
# 10        Bundle  transaction
# 11        Bundle  transaction
# 12        Bundle  transaction
# 13        Bundle  transaction
# 14        Bundle  transaction
# 15        Bundle  transaction
# 16        Bundle  transaction
# 17        Bundle  transaction
# 18        Bundle  transaction
# 19        Bundle  transaction
# 20        Bundle  transaction
# 21        Bundle  transaction
# 22        Bundle  transaction
# 23        Bundle  transaction
# 24        Bundle  transaction
# 25        Bundle  transaction
# 26        Bundle  transaction
# 27        Bundle  transaction
# 28        Bundle  transaction
# 29        Bundle  transaction
# ...
